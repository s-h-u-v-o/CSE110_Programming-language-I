# %%
#Task_1.1
msg= input('write a message: ')
print(msg)
num= int(input('write a number :'))
print(num)
# Out:
# write a message: hello world
# hello world
# write a number :21
# 21

# %%
#Task_1.2
x= int(input('1st number: '))
y= int(input('2nd number: '))
print('summation:', x+y)
print('multiplication:', x*y)
# Out:
# 1st number: 10
# 2nd number: 5
# summation: 15
# multiplication: 50

# %%
print('hello',hi')
# Out:
#   File "<ipython-input-3-3a52b750bc85>", line 1
#     print('hello',hi')
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#Task_1.3
x= int(input('1st number: '))
y= float(input('2nd number: '))
print((x+y),(x-y))
# Out:
# 1st number: 4
# 2nd number: 5
# 9.0 -1.0

# %%
#Task_1.4
x= int(input('1st number: '))
y= int(input('2nd number: '))
y= float(y)
print(str(x)+str(y))
# Out:
# 1st number: 2
# 2nd number: 3
# 23.0

# %%
#Task_2
M= int(input('base: '))
N= int(input('power: '))
print(str(M)+'^'+str(N)+':',M**N)

# %%
#Task_3
x= int(input('given shipment load= '))
y= x//4
print('maximum load=',y*4)
# Out:
# given shipment load= 9
# maximum load= 8

# %%
#1
A= int(input())
B= int(input())
C= int(input())
D= float(input())

print(int(A**C+(2*B)*(A//2)-D/3))
# Out:
# 9
# 100
# 1
# 3.7
# 807

# %%
#2
a= input('First Name: ')
b= input('Last Name: ')
c= int(input('Age: '))
d= float(input('CGPA: '))

print('Name:',a,'Rahman')
print('Age:',c-2)
print('CGPA:',d+0.25)
# Out:
# First Name: Labiba
# Last Name: Arif
# Age: 23
# CGPA: 3.7
# Name: Labiba Rahman
# Age: 21
# CGPA: 3.95

# %%
x=6
y=10
a=True
b=False
y=x
x-=2
x=x+2
x//=1
print(x==y-2)
# Out:
# False

# %%
x=int(input('total chocolates: '))
print('Each friend will receive',x//3,'chocolates''\n''jyfhj')
print()
# Out:
# total chocolates: 90
# Each friend will receive 30 chocolates
# jyfhj
